# %% [markdown]
# ### Viscosímetro de Tambor Cónico
#
# _G. Raush_
#
# _Setiembre 2022_
#
# _**Departamento de Mecànica de Fluids-UPC**_

# %% [markdown]
# Un cono sólido de ángulo $2\theta$ , radio de basae $r_0$ y densidad $\rho_c$ está girando a una velocidad angular $\omega_0$ en un asiento cónico , como se muestra en la Figura. La holgura $h$ entre ambos se llena con aceite de viscosidad $\mu$. Despreciando la resistencia del aire, derivar una expresión analítica para :
#
# a) el momento para una velocidad angular $\omega$ constante.
#
# b) la velocidad angular del cono $\omega(t)$ si no hay un par aplicado.

# %% [markdown]
# ![viscosimetroConico.png](attachment:6085d2dc-aa25-420a-bbcc-6ab45cb2fb62.png)
